                 [ 0.9099375009536743, 0.8974124789237976, 0.9043874740600586, 0.9519750475883484, 0.9507499933242798, 0.9601186513900757, 0.9580437541007996, 0.9472000002861023, 0.9555686712265015, 0.9498624801635742, 0.9609125256538391, 0.9419124722480774],
                 [ 0.8844750523567200, 0.9116188287734985, 0.9319062232971191, 0.9504812955856323, 0.9101437330245972, 0.9506062269210815, 0.9613437652587891, 0.9508749842643738, 0.9581562280654907, 0.9564062952995300, 0.9555875062942505, 0.9494500160217285],
                 [ 0.9198125004768372, 0.9116061925888062, 0.9324625134468079, 0.9389436841011047, 0.9377375841140747, 0.9468625187873840, 0.9532812237739563, 0.9630249738693237, 0.9365750551223755, 0.9477688074111938, 0.9424875378608704, 0.948468804359436],
                 [ 0.7954562306404114, 0.9404312968254089, 0.9435124397277832, 0.9528124928474426, 0.9553999900817871, 0.9629124402999878, 0.9593563079833984, 0.9570375680923462, 0.9580937623977661, 0.9614499807357788, 0.9602437019348145, 0.8907938003540039]])

fwmnist = np.array([[0.7615000605583191, 0.7567343711853027, 0.7505260109901428, 0.7379192709922790, 0.6748984456062317],
                    [0.7701301574707031, 0.7510625720024109, 0.7677421569824219, 0.7007786631584167, 0.6753463745117188],
                    [0.7531719207763672, 0.7567030787467957, 0.7540807723999023, 0.7484583258628845, 0.7037943005561829],
                    [0.7516067624092102, 0.7566172480583191, 0.7360885143280029, 0.7284088134765625, 0.6784947514533997]])

automnist = np.array([[0.6315104365348816, 0.624098539352417, 0.2940705120563507, 0.13511618971824646, 0.11227964609861374]])

detail = np.array([[0.6804265975952148, 0.7361468076705933, 0.7348906397819519, 0.7481764554977417, 0.7546828389167786]])


fw_ar = (fast, [0.75,1.25,0.75,0.25], 1.0, "fast_weights_ar", "eta")
auto_ar = (auto, [0.0725, 0.1325, 32.5, 2.5], 0.001, "autoconceptor_ar", "alpha")
fw_mnist = (fwmnist, [0.75,1.25,0.75,0.35], 0.8, "fast_weights_mnist28", "eta")
auto_mnist_1 = (automnist, [0.005,0.055, 21, 19], 0.005, "autoconceptor_mnist28_1", "alpha")
auto_mnist_2 = (detail, [0.000,0.01, 21, 19], 0.001, "autoconceptor_mnist28_2", "alpha")

# %%
def plot_and_save(data_obj):
    data, extent, aspect, filename, ylabel = data_obj
    plt.figure(figsize = (10,10))
    #extent=[0.85, 1.25, 0.75, 0.25]
    #extent=[0.0725, 0.1325, 32.5, 2.5]
    #extent=[0.75,1.25,0.75,0.25]
    #extent=[0.000,0.01,21,19]
    res = plt.imshow(data, cmap='hot', interpolation='nearest',aspect=aspect,extent=extent)
    #extent=[unten links, unten rechts, unten links, oben links]
    plt.xlabel("lambda")
    plt.ylabel(ylabel) 
    plt.savefig("heatmap_"+filename+".png")
    plt.show()

# %%
plot_and_save(auto_ar)
